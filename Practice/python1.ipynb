# %%
print("hello world")
# Out:
# hello world

# %%
import sys
print(sys.version)
# Out:
# 3.12.7 | packaged by Anaconda, Inc. | (main, Oct  4 2024, 13:17:27) [MSC v.1929 64 bit (AMD64)]

# %%
if 5>2:
    print("five is greater than 2")
# Out:
# five is greater than 2

# %%
x=5
y="hello world "

# %%
print(x)
# Out:
# 5

# %%
print(x);print(y)
# Out:
# 5
# hello world

# %%
print("Hello World!")
print("Have a good day.")
print("Learning Python is fun!")
# Out:
# Hello World!
# Have a good day.
# Learning Python is fun!

# %%
print("Vinay is the cirminal ",end="")
print("but he loves a lot dhanya")
# Out:
# Vinay is the cirminal but he loves a lot dhanya

# %%
a=25
print(f"I am {a}")  ## statement
# Out:
# I am 25

# %%
s=str(3)

# %%
type(s)
# Out:
# str

# %%
y=int(3)

# %%
type(y)
# Out:
# int

# %%
z=float(3)

# %%
type(z)
# Out:
# float

# %%
fruits=["apple","banana","cherry"]
x,y,z=fruits
print(x)
print(y)
# Out:
# apple
# banana

# %%
print(z)
# Out:
# cherry

# %%
bro="vinay"
print(len(bro))
# Out:
# 5

# %%
txt="The best things in life are free!"
if "free" not in txt:
    print("Yes.'free' is present")

# %%
bro="browhat is the fucntking this are u doing this time "
dhanya=2
naina=[bro[i:i+dhanya] for i in range(0,len(bro),dhanya)] 
print(naina)
# Out:
# ['br', 'ow', 'ha', 't ', 'is', ' t', 'he', ' f', 'uc', 'nt', 'ki', 'ng', ' t', 'hi', 's ', 'ar', 'e ', 'u ', 'do', 'in', 'g ', 'th', 'is', ' t', 'im', 'e ']

# %%
a="Hello World"
a.upper()
# Out:
# 'HELLO WORLD'

# %%
a.lower()
# Out:
# 'hello world'

# %%
s=" "
a=a.lower()
for i in a:
    if i.isupper():
        i=i.lower()
        s+=i

# %%
a.replace('e','h')
# Out:
# 'hhllo world'

# %%
dhanya=a.split(" ")

# %%
dhanya
# Out:
# ['hello', 'world']

# %%
bro=""
for i in dhanya:
    bro+=i
    bro+=" "

# %%
dhanya=bro.capitalize

# %%
dhanya
# Out:
# <function str.capitalize()>

# %%
bro="marjaunga"

# %%
bro.capitalize()
# Out:
# 'Marjaunga'

# %%
bro.casefold()
# Out:
# 'marjaunga'

# %%
bro.center(4)
# Out:
# 'marjaunga'

# %%
x
# Out:
# '0000000marjaunga0000000'

# %%
x=bro.rjust(5,"#")

# %%
x
# Out:
# 'marjaunga'

# %%
bro.count('m')
# Out:
# 1

# %%
bro="brofagkrh"
dhanya=bro.encode()

# %%
dhanya
# Out:
# b'brofagkrh'

# %%
bro="Vinay"

# %%
bro.isspace()
# Out:
# False

# %%
bro.istitle()
dhanya=""

# %%
dhanya.join("bro")
# Out:
# 'bro'

# %%
txt = "apple-banana-cherry"

result = txt.rpartition("-")

print(result)
# Out:
# ('apple-banana', '-', 'cherry')

# %%
txt = "one, two, three, four"

# Limit to only 1 split from the right
result = txt.rsplit(", ", 2)

print(result)
# Out:
# ['one, two', 'three', 'four']

# %%
# Step 1: Map 'S' -> 'P' and 'h' -> 'e'
mytable = str.maketrans("Sh", "Pe")

txt = "Hello Sam!"

# Step 2: Translate the string
print(txt.translate(mytable))
# Out:
# Hello Pam!

# %%
numbers = [1, 2, 3, 4, 5]

if (count := len(numbers)) > 3:  ## walrus operator assign vlaues ot 
    print(f"List has {count} elements")
# Out:
# List has 5 elements

# %%
num=4

x="weekend" if num>5 else "vinay sharma"

# %%
x
# Out:
# 'vinay sharma'

# %%
x=x.split(" ")

# %%
bro=" "
for i in x:
    bro+=i
    bro+=" "

# %%
bro
# Out:
# ' vinay sharma '

# %%
dhanya="vinay"
vinay="dhanya"

dhanya==dhanya
# Out:
# True

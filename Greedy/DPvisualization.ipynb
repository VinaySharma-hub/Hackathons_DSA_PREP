# %% [markdown]
# solve(6)
#
# ├── use 1 → solve(5)
#
# │   ├── use 1 → solve(4)
#
# │   │   ├── use 1 → solve(3)
#
# │   │   │   ├── use 1 → solve(2)
#
# │   │   │   │   ├── use 1 → solve(1)
#
# │   │   │   │   │   ├── use 1 → solve(0) ✔
#
# │   │   │   │   │   ├── use 3 → solve(-2) ✘
#
# │   │   │   │   │   └── use 4 → solve(-3) ✘
#
# │   │   │   │   ├── use 3 → solve(-1) ✘
#
# │   │   │   │   └── use 4 → solve(-2) ✘
#
# │   │   │   ├── use 3 → solve(0) ✔
#
# │   │   │   └── use 4 → solve(-1) ✘
#
# │   │   ├── use 3 → solve(1)
#
# │   │   └── use 4 → solve(0) ✔
#
# │   ├── use 3 → solve(2)
#
# │   └── use 4 → solve(1)
#
# ├── use 3 → solve(3)
#
# │   ├── use 1 → solve(2)
#
# │   ├── use 3 → solve(0) ✔
#
# │   └── use 4 → solve(-1) ✘
#
# └── use 4 → solve(2)
#
#     ├── use 1 → solve(1)
#
#     ├── use 3 → solve(-1) ✘
#
#     └── use 4 → solve(-2) ✘
